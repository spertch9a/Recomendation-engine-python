# %% [markdown]
# This chapter we'll find the users that havve the most similar prefrences, and based on these prefrences  we can make suggestions
# this form of sugestion is called colaborative filtering
# the prediciton of filtering of the items
# that might interest the user based on the prefrences of similar users
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
